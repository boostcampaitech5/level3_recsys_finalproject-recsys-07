# %%
import os
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

df_dev = pd.read_csv('../data/durecdial/dev_data_pp.csv')

# %%
print(df_dev)
# Out:
#        user_id user_profile_age_range                 user_profile_name  \
# 0            0      Over 50 years old               Jacky Cheung's news
# 1            0      Over 50 years old               Jacky Cheung's news
# 2            0      Over 50 years old               Jacky Cheung's news
# 3            0      Over 50 years old               Jacky Cheung's news
# 4            0      Over 50 years old               Jacky Cheung's news
# ...        ...                    ...                               ...
# 12652      810     Under 18 years old  Bo Huang's news; Jay Chou's news
# 12653      810     Under 18 years old  Bo Huang's news; Jay Chou's news
# 12654      810     Under 18 years old  Bo Huang's news; Jay Chou's news
# 12655      810     Under 18 years old  Bo Huang's news; Jay Chou's news
# 12656      810     Under 18 years old  Bo Huang's news; Jay Chou's news
#
#       user_profile_residence user_profile_accepted_food  \
# 0                   Jiujiang   ['Wanzhou Roasted Fish']
# 1                   Jiujiang   ['Wanzhou Roasted Fish']
# 2                   Jiujiang   ['Wanzhou Roasted Fish']
# 3                   Jiujiang   ['Wanzhou Roasted Fish']
# 4                   Jiujiang   ['Wanzhou Roasted Fish']
# ...                      ...                        ...
# 12652                Luoyang                        NaN
# 12653                Luoyang                        NaN
# 12654                Luoyang                        NaN
# 12655                Luoyang                        NaN
# 12656                Luoyang                        NaN
#
#       user_profile_accepted_movies  \
# 0               ['Marinated Fish']
# 1               ['Marinated Fish']
# 2               ['Marinated Fish']
# 3               ['Marinated Fish']
# 4               ['Marinated Fish']
# ...                            ...
# 12652                ['Mapo Tofu']
# 12653                ['Mapo Tofu']
# 12654                ['Mapo Tofu']
# 12655                ['Mapo Tofu']
# 12656                ['Mapo Tofu']
#
#                              user_profile_accepted_music  \
# 0      ['The Best Voice', 'If Its Not Love', 'The Cre...
# 1      ['The Best Voice', 'If Its Not Love', 'The Cre...
# 2      ['The Best Voice', 'If Its Not Love', 'The Cre...
# 3      ['The Best Voice', 'If Its Not Love', 'The Cre...
# 4      ['The Best Voice', 'If Its Not Love', 'The Cre...
# ...                                                  ...
# 12652  ['How Are You', 'Rain', 'Dear Child', 'Magicia...
# 12653  ['How Are You', 'Rain', 'Dear Child', 'Magicia...
# 12654  ['How Are You', 'Rain', 'Dear Child', 'Magicia...
# 12655  ['How Are You', 'Rain', 'Dear Child', 'Magicia...
# 12656  ['How Are You', 'Rain', 'Dear Child', 'Magicia...
#
#                              user_profile_rejected_music user_profile_gender  \
# 0                        ['Blessing', 'Hard to Go Back']                Male
# 1                        ['Blessing', 'Hard to Go Back']                Male
# 2                        ['Blessing', 'Hard to Go Back']                Male
# 3                        ['Blessing', 'Hard to Go Back']                Male
# 4                        ['Blessing', 'Hard to Go Back']                Male
# ...                                                  ...                 ...
# 12652  ['Self Directed Act', 'A Branch of Plum Blosso...              Female
# 12653  ['Self Directed Act', 'A Branch of Plum Blosso...              Female
# 12654  ['Self Directed Act', 'A Branch of Plum Blosso...              Female
# 12655  ['Self Directed Act', 'A Branch of Plum Blosso...              Female
# 12656  ['Self Directed Act', 'A Branch of Plum Blosso...              Female
#
#       user_profile_accepted_celebrities  ...  time    place        date topic  \
# 0                      ['Jacky Cheung']  ...   7:0      NaN   2018-10-4   NaN
# 1                      ['Jacky Cheung']  ...   7:0      NaN   2018-10-4   NaN
# 2                      ['Jacky Cheung']  ...   7:0      NaN   2018-10-4   NaN
# 3                      ['Jacky Cheung']  ...   7:0      NaN   2018-10-4   NaN
# 4                      ['Jacky Cheung']  ...   7:0      NaN   2018-10-4   NaN
# ...                                 ...  ...   ...      ...         ...   ...
# 12652          ['Bo Huang', 'Jay Chou']  ...  22:0  at home  2018-11-21   NaN
# 12653          ['Bo Huang', 'Jay Chou']  ...  22:0  at home  2018-11-21   NaN
# 12654          ['Bo Huang', 'Jay Chou']  ...  22:0  at home  2018-11-21   NaN
# 12655          ['Bo Huang', 'Jay Chou']  ...  22:0  at home  2018-11-21   NaN
# 12656          ['Bo Huang', 'Jay Chou']  ...  22:0  at home  2018-11-21   NaN
#
#             wday sentence_index  \
# 0            NaN              0
# 1            NaN              1
# 2            NaN              2
# 3            NaN              3
# 4            NaN              4
# ...          ...            ...
# 12652  Wednesday              3
# 12653  Wednesday              4
# 12654  Wednesday              5
# 12655  Wednesday              6
# 12656  Wednesday              7
#
#                                                 sentence  \
# 0                         What's the weather like today?
# 1      It's sunny with north winds in Jiujiang today....
# 2                         That's great. That's detailed.
# 3               It's nice weather to rat Marinated Fish.
# 4          Yo, you even know my favorite Marinated Fish.
# ...                                                  ...
# 12652  Yeah. It will turn from sunny to cloudy with n...
# 12653  The weather forecast is quite accurate. I like...
# 12654                                         Thank you.
# 12655              I'm going to have a rest. Talk later!
# 12656                                    All right. Bye!
#
#                  goal_topic             goal_type  \
# 0         Ask about weather     Ask about weather
# 1         Ask about weather     Ask about weather
# 2         Ask about weather     Ask about weather
# 3            Marinated Fish   Food recommendation
# 4            Marinated Fish   Food recommendation
# ...                     ...                   ...
# 12652  Weather notification  Weather notification
# 12653  Weather notification  Weather notification
# 12654  Weather notification  Weather notification
# 12655           Say goodbye           Say goodbye
# 12656           Say goodbye           Say goodbye
#
#                                                knowledge
# 0      Jiujiang, 2018-10-4, Sunny with north winds. T...
# 1      Jiujiang, 2018-10-4, Sunny with north winds. T...
# 2                                                    NaN
# 3      Sunny with north winds. The high will be 27 ℃,...
# 4                                                    NaN
# ...                                                  ...
# 12652  Luoyang, 2018-11-21, Sunny early and mostly cl...
# 12653                                                NaN
# 12654                                                NaN
# 12655                                                NaN
# 12656                                                NaN
#
# [12657 rows x 29 columns]

# %%
import nltk
import re
# nltk.download('stopwords')
# nltk.download('averaged_perceptron_tagger')
# nltk.download('all')
from nltk.util import ngrams
from nltk.corpus import stopwords
from stop_words import get_stop_words

# 각 instance 별로 문장들을 어레이에 넣는다
dialogues = df_dev.groupby('user_id')
stop_words = list(get_stop_words('en'))         #About 900 stopwords
nltk_words = list(stopwords.words('english')) #About 150 stopwords
stop_words.extend(nltk_words)

def distinct_n_s_level(sentence, n):
    if len(sentence) == 0:
        return 0.0
    word_list = re.findall(r'\w+', i,flags = re.UNICODE)
    filtered_words = [word for word in word_list if word not in stopwords.words('english')]
    output = ' '.join([w for w in filtered_words if not w in stop_words])
    NGRAMS = ngrams(nltk.word_tokenize(output), 1)
    D_NGRAMS = set(NGRAMS)
    s_dngram = len(D_NGRAMS)/len(word_list)
    return s_dngram

d_array = [] # 1. 각 대화 별 s_dngram 평균을 저장한다. length = # of dialogues
ss_array = []
for key, item in dialogues:
    # per dialogue
    # 각 어레이(instance) 별로 sentence level distinct n-gram을 계산한다.
    # 계산 방법 : https://github.com/neural-dialogue-metrics/Distinct-N/blob/main/distinct_n/metrics.py#L3
    s_group = dialogues.get_group(key)['sentence']
    s_word_len = []
    # s-level dngram 저장하는 array
    s_array = []
    for i in s_group:
        s_array.append(distinct_n_s_level(i, 1))
    # dialogue-level distinct ngram : average distinct-N of a list of sentences (the dialogue)
    ss_array.append(s_array)
    d_dngram = sum(s_array)/len(s_group)
    d_array.append(d_dngram)
avg_dataset = sum(d_array)/len(d_array) # 2. 전체 데이터셋의 d_dngram 평균값. type = float
# print(d_array)

# print(avg_dataset)

# %%
# 유의미한 값 1. avg_dataset 변수, 2. d_array 어레이
# avg_dataset : Dialogue-level distinct n-gram들의 평균값 (float)
# d_array : Sentence-level distinct n-gram들의 평균, 한 dialogue의 평균 distinct n-gram)들의 어레이.

# %%
# d_array의 분포를 시각화한다.
import plotly.figure_factory as ff
import numpy as np

group_labels = ['Distinct N-gram'] # name of the dataset

fig = ff.create_distplot([d_array], group_labels, bin_size = .1)
fig.update_layout(
    autosize = False,
    width = 800,
    height = 800,
    yaxis=dict(
        title_text="Dialogue Count",
    ),
    title_text='Distribution of Dialogue-level Distinct N-gram')
fig.update_yaxes(automargin=True)
fig.show()
# Out:
# <div>                            <div id="16865f42-7dad-4ef8-9610-7088ac5af677" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16865f42-7dad-4ef8-9610-7088ac5af677")) {                    Plotly.newPlot(                        "16865f42-7dad-4ef8-9610-7088ac5af677",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"Distinct N-gram","marker":{"color":"rgb(31, 119, 180)"},"name":"Distinct N-gram","opacity":0.7,"x":[0.6471781305114638,0.5269345238095238,0.5787328797745465,0.7296559343434343,0.5977742469518785,0.6693248709233364,0.6960227272727273,0.6154801988135321,0.5508248754047074,0.5559314954051796,0.6356154742598793,0.53398033126294,0.6406462585034014,0.737379374098124,0.6059733669108669,0.6102716312974464,0.598713967192228,0.6771255060728744,0.6513071254142683,0.6792379842379843,0.6170550701341142,0